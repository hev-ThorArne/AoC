# %%
import pandas as pd
import itertools
import re
import numpy as np

# %%
with open('input.txt') as f:
    lines = [line.rstrip() for line in f]

# %%
instructions = lines[0]
network = lines[2:len(lines)+1]

# %%
#%%timeit
start_l = []
left_element_l = []
right_element_l = []
network_dict = dict()
for line in network:
    start = line.split("=")[0][0:3]
    left_element = line.split()[2][1:4]
    right_element = line.split()[3][0:3]
    start_l.append(start)
    # left_element_l.append(left_element)
    # right_element_l.append(right_element)
    network_dict.update({start: [left_element,right_element]})

# %%
i = 0
counter = 0
steps = 0
next = "AAA"
end = "ZZZ"
element_list = []
while next != "ZZZ":
    instruction = instructions[i]
    # print(instruction)
    if instruction == "L":
        next = network_dict[next][0]

    elif instruction == "R":
        next = network_dict[next][1]
    
    # for start in start_l:
    #     if start != next:
    #         if counter >= len(left_element_l)-1:
    #             counter = 0
    #         else:
    #             counter += 1

    steps += 1
    # print(next)

    

    if i >= len(instructions)-1:
        i = 0
    else:
        i += 1
# svar oppgave 1
steps
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\57947\Programmering\AdventOfCode\08\dag8.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/57947/Programmering/AdventOfCode/08/dag8.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> # print(instruction)
#      <a href='vscode-notebook-cell:/c%3A/Users/57947/Programmering/AdventOfCode/08/dag8.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> if instruction == "L":
# ---> <a href='vscode-notebook-cell:/c%3A/Users/57947/Programmering/AdventOfCode/08/dag8.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     next = network_dict[next][0]
#      <a href='vscode-notebook-cell:/c%3A/Users/57947/Programmering/AdventOfCode/08/dag8.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a> elif instruction == "R":
# ...

# %%
with open('input.txt') as f:
    lines = [line.rstrip() for line in f]
instructions = lines[0]
network = lines[2:len(lines)+1]

network_dict = dict()
for line in network:
    start = line.split("=")[0][0:3]
    left_element = line.split()[2][1:4]
    right_element = line.split()[3][0:3]
    network_dict.update({start: [left_element,right_element]})


starting_keys = [key for key, value in network_dict.items() if key.endswith("A")]
ends = [0] * len(starting_keys)
i = 0
for keys in starting_keys:
    ends[i] = keys[2]
    i += 1

# %%
nexts = []
i = 0
steps = 0 
ends = [0] * len(starting_keys)
ending_point = ["Z"] * len(starting_keys)
nexts = starting_keys
while ends != ending_point:
    
    instruction = instructions[i]
    # print(instruction)
    if instruction == "L":
        nexts = [network_dict[x][0] for x in nexts]
        ends = [nexts[x][2] for x in range(len(nexts))]

    elif instruction == "R":
        nexts = [network_dict[x][1] for x in nexts]
        ends = [nexts[x][2] for x in range(len(nexts))]
    #print(nexts)
    steps += 1
    if i >= len(instructions)-1:
        i = 0
    else:
        i += 1

    if steps % 1000000 == 0:
        print(steps)
steps
# livet er ikke langt nok til å vente på denne..
# Out:
# 1000000
# 2000000
# 3000000
# 4000000
# 5000000
# 6000000
# 7000000
# 8000000
# 9000000
# 10000000
# 11000000
# 12000000
# 13000000
# 14000000
# 15000000
# 16000000
# 17000000
# 18000000
# 19000000
# 20000000
# 21000000
# 22000000
# 23000000
# 24000000
# 25000000
# 26000000
# 27000000
# 28000000
# 29000000
# 30000000
# 31000000
# 32000000
# 33000000
# 34000000
# 35000000
# 36000000
# 37000000
# 38000000
# 39000000
# 40000000
# 41000000
# 42000000
# 43000000
# 44000000
# 45000000
# 46000000
# 47000000
# 48000000
# 49000000
# 50000000
# 51000000
# 52000000
# 53000000
# 54000000
# 55000000
# 56000000
# 57000000
# 58000000
# 59000000
# 60000000
# 61000000
# 62000000
# 63000000
# 64000000
# 65000000
# 66000000
# 67000000
# 68000000
# 69000000
# 70000000
# 71000000
# 72000000
# 73000000
# 74000000
# 75000000
# 76000000
# 77000000
# 78000000
# 79000000
# 80000000
# 81000000
# 82000000
# 83000000
# 84000000
# 85000000
# 86000000
# 87000000
# 88000000
# 89000000
# 90000000
# 91000000
# ...

# %%
nexts = [network_dict[x][0] for x in starting_keys]
print(nexts)
nexts = [network_dict[x][1] for x in nexts]
print(nexts)
nexts = [network_dict[x][0] for x in nexts]
print(nexts)
nexts = [network_dict[x][1] for x in nexts]
print(nexts)
nexts = [network_dict[x][0] for x in nexts]
print(nexts)
nexts = [network_dict[x][1] for x in nexts]
print(nexts)
# Out:
# ['11B', '22B']
# ['11Z', '22C']
# ['11B', '22Z']
# ['11Z', '22B']
# ['11B', '22C']
# ['11Z', '22Z']

# %%
ends = [nexts[x][2] for x in range(len(nexts))]
